# %% [markdown]
# - Создаем меню
# ```html
# <div class="menu"></div>
# ```
# - Добавляем в меню кнопки. Каждая кнопка содержит иконку и название.
#   - Иконки можно найти в интернете, например:
#     - https://www.svgrepo.com/collection/dazzle-line-icons/ (Можно как скачать, так и указать ссылку на иконку с этого сайта. Нажмите правой кнопкой "Скопировать URL картинки")
#     - https://fonts.google.com/icons (Можно настроить и скачать, либо справа есть инструкция как подключить иконки к сайту)
# - После меню создаем div с множеством каких-нибудь элементов (не забудьте добавить им размер и цвет)
#   ```html
#     <div class="list"></div>
#     <script>
#         /*Спойлеры*/
#         /*Javascript код для добавления 50-и div в list*/
#         const list = document.querySelector('.list');
#
#         for (let i = 0; i < 50; i++) {
#             const box = document.createElement('div');
#             box.classList.add('box');
#             list.appendChild(box);
#         }
#     </script>
#   ```
#   - Для элементов такого типа не обязательно писать много медиазапросов и по разному выравнивать элементы. Можно воспользоваться свойствами Flexbox для переноса элементов. Но если элементы разные и разного размера, то лучше настраивать с помощью медиазапросов.
#   - Чтобы элементы не оставляли много пустого простарнство в строке добавьте им растяжение с помощью `flex-grow`
#   ![image-4.png](attachment:image-4.png)
# - Выравниваем содержимое кнопок
#   - Для
#     ```css
#         .menu {
#             display: flex;
#             flex-direction: row;
#             justify-content: flex-start;
#             align-items:flex-start;;
#             width: 100%;
#             font-family: 'Roboto';
#             font-size: 22px;
#         }
#     ```
#   - Для удобства выравнивания можно добавлять дополнительные контейнеры. Зачастую удобнее выравнивать содержимое когда оно не просто стоит подряд внутри родительского контейнера
#     ```html
#         <div class="menu">
#             <div class="menu-button">
#                 <img src="дом.svg">
#                 Главная
#             </div>
#             ...
#         </div>
#     ```
#     А содержимое по отдельности обернуто в контейнеры
#     ```html
#     <div class="menu">
#         <div class="menu-button">
#             <div class="menu-button-icon">
#                 <img src="дом.svg">
#             </div>
#             <div class="menu-button-name">
#                 Главная
#             </div>
#         </div>
#         ...
#     </div>
#      ```
#     ![image-3.png](attachment:image-3.png)
#     В этом случае можно настраивать не только размер содержимого, но и сколько под него отведено места*.
#
#
#
#     ![image-2.png](attachment:image-2.png)
# - Украшаем
#     - Подбором цветов выполняется не только на личный вкус, но и с учетом сочетания и восприятия цветов. https://aipa.ru/content/34-garmonichnye-sochetaniya-cvetov-cvetovoj-krug-jokhanessa-ittena
#     Для ускорения работы можно воспользоваться сервисами, например:
#       - https://couleur.io/ (внизу есть примеры использования набора цветов на сайте)
#       - https://coolors.co/generate (Можно сгенерировать случайно или догенерировать с учетом закрепленных цветов)
#
#     - Цвета для можете подобрать самостоятельно:
#         ```css
#             body {
#                 background-color: #??????;
#             }
#             .menu-button{
#                 background-color: #??????;
#             }
#             .menu-button:hover{
#                  background-color: #??????;
#                 /*Добавьте как изменяет цвет кнопка при наведении, чтобы она не была просто статичной*/
#             }
#         ```
#     - Перекрасить .svg (векторный формат) иконки легко, в отличии от растровых форматов, но для этого все равно нужно редактировать файл. Другой вариант - перекрасить иконку на самом сайте с помощью фильтров. Фильтр для перекрашивания в нужный вам цвет можно сгенерировать на сайте:
#     https://angel-rs.github.io/css-color-filter-generator/
#
#         ```css
#         .menu-button-icon > img{
#             /*Пример*/
#             filter: brightness(0) saturate(100%) invert(10%) sepia(97%) saturate(5502%) hue-rotate(160deg) brightness(98%) contrast(101%);
#         }
#         ```
#     - На свое усмотрение добавляем отступы, чтобы элементы не сливались
# - Адаптируем
#   - С помощью медиазапросов изменяем положение кнопок, когда им будет не хватать места
#
#     ```css
#     @media screen and (max-width: ...px) {
#         .menu {
#             /*Меняем горизонтальное расположение на вертикальное*/
#         }
#         /*Изменяем стили, чтобы кнопки выглядил ровно*/
#         .menu-button {...}
#         .menu-button-name {...}
#         .menu-button-icon {...}
#     }
#     ```
#     В этом примере все иконки выровнены по одной линии в середине.
#     ![image.png](attachment:image.png)
#     Такие меню обычно скрываются по кнопки, но для этого нужен Javascript, который будет в следующей теме.
# - Проверяем все ли элементы красиво выглядят при любом размере окна. При необходимости добавляем стили и медиазапросы.
#
# ---
# \* При разработке сайтов задача не сделать правильную структуру, а сделать так, чтобы
# - сайт работал правильно
# - сайт выглядил красиво и правильно на разных устройствах
#
# красивость и правильность определяется заказчиком.
# Поэтому если хотите и можете, то делайте другими способами.
