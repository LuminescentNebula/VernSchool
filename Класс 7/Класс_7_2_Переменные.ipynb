# %% [markdown]
# # Переменные

# %% [markdown]
# Переменная – это величина, имеющая имя, тип и значение. Значение переменной можно изменять во время работы программы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Имя переменной

# %% [markdown]
# 1) Имя переменной может только содержать буквы, цифры и знак подчеркивания.
# (A-Z, a-z, 0-9, _)
#
# 2) Имя переменной должно начинаться с буквы или символа подчеркивания
#
# 3) Имена переменных чувствительны к регистру
#
# 4) Имя переменной не должно совпадать с зарезервированным ключевым словом.

# %%
import keyword
print("Зарезервированные ключевые слова:",*keyword.kwlist)
# Out:
# Зарезервированные ключевые слова: False None True and as assert async await break class continue def del elif else except finally for from global if import in is lambda nonlocal not or pass raise return try while with yield

# %% [markdown]
# ## Запись значений

# %% [markdown]
# Для записи значений в переменную используется оператор присваивания `=`.
# При записи нового значения старое удаляется из памяти.

# %%
a = 5 # Присваиваем значение 5
print(a) # Выводим значение перемнной a
a = 7 # Присваиваем значение 7
print(a) # Выводим значение перемнной a
# Out:
# 5
# 7

# %% [markdown]
# ## Типы переменных

# %% [markdown]
# Python использует динамическую типизацию, поэтому заранее тип переменной не указывается. Также это обозначает, что вы можете изменить тип перменной.

# %% [markdown]
# ### Основные типы данных

# %% [markdown]
# Тип можно определить с помощью функции `type()`

# %% [markdown]
# Integer - целое число. В python обозначается как int

# %%
a = 4
print ( type(a) )
# Out:
# <class 'int'>

# %% [markdown]
# Float - вещественное число

# %%
a = 4.5
print ( type(a) )
# Out:
# <class 'float'>

# %% [markdown]
# String - символьная строка. В python обозначается как str

# %%
a = "Вася"
print ( type(a) )
# Out:
# <class 'str'>

# %% [markdown]
# Boolean - Логическое значение (ИСТИНА или ЛОЖЬ). В python обозначается как bool

# %%
a = True
print ( type(a) )
# Out:
# <class 'bool'>

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ## Изменение значений переменной

# %% [markdown]
# Значения переменных можно изменять используя уже существующие значения этой или других перменных.

# %%
a = 3
b = a + 2
a = (a + 3)*(b - 2)
b = b + 1
print(a,b)
# Out:
# 18 6

# %% [markdown]
# `a = b` обозначает присваивание перменной `a` значение переменной `b`, а не то что переменная `a` равна переменной `b`.

# %% [markdown]
# ## Ввод значения с клавиатуры

# %% [markdown]
# Функция `input()` позволяет ввести **строку** с клавиатуры. В `()` можно написать подсказку, которая будет выводиться перед ожиданием ввода (необязательно).

# %%
input("Введите число:")
# Out:
# Введите число:12
# '12'

# %%
a = input()
print("Было введено:",a)
# Out:
# abcde
# Было введено: abcde

# %% [markdown]
# Поскольку вводятся именно строки, то полученные значения нельзя сразу использовать как числа

# %%
a = input()
b = input()
c = a + b
print(c)
# Out:
# 12
# 33
# 1233

# %% [markdown]
# Сначала их нужно преобразовать

# %%
a = int( input() )
b = int( input() )
c = a + b
print(c)
# Out:
# 12
# 33
# 45

# %% [markdown]
# ## Вывод данных через format

# %% [markdown]
# Для вывода данных удобно использовать форматированные строки. Одни и те же данные можно вывести разным способом:

# %%
a=1;b=2;c=3
print(a, "+", b, "=", c, sep = "" ) 
print("{}+{}={}".format(a, b, c))
print(f"{a}+{b}={c}")
# Out:
# 1+2=3
# 1+2=3
# 1+2=3

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# # Задание

# %% [markdown]
# На оценку 3 нужно выполнить задание «3».
#
# На оценку 4 нужно выполнить задания «3» и «4».
#
# На оценку 5 нужно выполнить задания «3», «4» и «5».
#
# Задание выполняется и сдается на компьютерах на этом уроке, либо выполняться дома и сдается на листочке на следующем уроке. Лучше на уроке.

# %% [markdown]
# «3»: Ввести три числа, найти их сумму. Пример:
# 	 Введите три числа:
# 	 4
# 	 5
# 	 7
# 	 `4+5+7=16`
#
#
# «4»: Ввести три числа, найти их сумму и произведение. Пример:
# 	 Введите три числа:
# 	 4
# 	 5
# 	 7
# 	 `4+5+7=16`
# 	 `4*5*7=140`
#
#
# «5»: Ввести три числа, найти их сумму, произведение и среднее арифметическое. Пример:
#      Введите три числа:
# 	 4
# 	 5
# 	 7
# 	 `4+5+7=16`
# 	 `4*5*7=140`
# 	 `(4+5+7)/3=5.333333`
